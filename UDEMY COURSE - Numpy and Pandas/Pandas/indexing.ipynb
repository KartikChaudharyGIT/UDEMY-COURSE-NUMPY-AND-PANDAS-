# %%
import pandas as pd

# %%
data = pd.read_csv("./data/titanic1.csv")
data
# Out:
#       pclass  survived                                               name  \
# 0        1.0       1.0                      Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                     Allison, Master. Hudson Trevor
# 2        1.0       0.0                       Allison, Miss. Helen Loraine
# 3        1.0       0.0               Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1.0       1.0                                Anderson, Mr. Harry
# 6        1.0       1.0                  Andrews, Miss. Kornelia Theodosia
# 7        1.0       0.0                             Andrews, Mr. Thomas Jr
# 8        1.0       1.0      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1.0       0.0                            Artagaveytia, Mr. Ramon
# 10       1.0       0.0                             Astor, Col. John Jacob
# 11       1.0       1.0  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
data["age"][:5]
# Out:
# 0    29.0000
# 1     0.9167
# 2     2.0000
# 3    30.0000
# 4    25.0000
# Name: age, dtype: float64

# %%
data[["age","fare"]][:5]
# Out:
#        age      fare
# 0  29.0000  211.3375
# 1   0.9167  151.5500
# 2   2.0000  151.5500
# 3  30.0000  151.5500
# 4  25.0000  151.5500

# %%
data.iloc[0]
# Out:
# pclass                                   1
# survived                                 1
# name         Allen, Miss. Elisabeth Walton
# sex                                 female
# age                                     29
# sibsp                                    0
# parch                                    0
# ticket                               24160
# fare                               211.338
# cabin                                   B5
# embarked                                 S
# boat                                     2
# body                                   NaN
# home.dest                     St Louis, MO
# Name: 0, dtype: object

# %%
data.iloc[5:10]
# Out:
#    pclass  survived                                           name     sex  \
# 5     1.0       1.0                            Anderson, Mr. Harry    male
# 6     1.0       1.0              Andrews, Miss. Kornelia Theodosia  female
# 7     1.0       0.0                         Andrews, Mr. Thomas Jr    male
# 8     1.0       1.0  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9     1.0       0.0                        Artagaveytia, Mr. Ramon    male
#
#     age  sibsp  parch    ticket     fare cabin embarked boat  body  \
# 5  48.0    0.0    0.0     19952  26.5500   E12        S    3   NaN
# 6  63.0    1.0    0.0     13502  77.9583    D7        S   10   NaN
# 7  39.0    0.0    0.0    112050   0.0000   A36        S  NaN   NaN
# 8  53.0    2.0    0.0     11769  51.4792  C101        S    D   NaN
# 9  71.0    0.0    0.0  PC 17609  49.5042   NaN        C  NaN  22.0
#
#              home.dest
# 5         New York, NY
# 6           Hudson, NY
# 7          Belfast, NI
# ...

# %%
data.iloc[0:5,10:15]
# Out:
#   embarked boat   body                        home.dest
# 0        S    2    NaN                     St Louis, MO
# 1        S   11    NaN  Montreal, PQ / Chesterville, ON
# 2        S  NaN    NaN  Montreal, PQ / Chesterville, ON
# 3        S  NaN  135.0  Montreal, PQ / Chesterville, ON
# 4        S  NaN    NaN  Montreal, PQ / Chesterville, ON

# %%
data = data.set_index("name")
data.head()
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                       1.0       1.0  female
# Allison, Master. Hudson Trevor                      1.0       1.0    male
# Allison, Miss. Helen Loraine                        1.0       0.0  female
# Allison, Mr. Hudson Joshua Creighton                1.0       0.0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)     1.0       0.0  female
#
#                                                      age  sibsp  parch  \
# name
# Allen, Miss. Elisabeth Walton                    29.0000    0.0    0.0
# Allison, Master. Hudson Trevor                    0.9167    1.0    2.0
# Allison, Miss. Helen Loraine                      2.0000    1.0    2.0
# Allison, Mr. Hudson Joshua Creighton             30.0000    1.0    2.0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.0000    1.0    2.0
#
#                                                  ticket      fare    cabin  \
# ...

# %%
data.loc["Allison, Miss. Helen Loraine"]
# Out:
# pclass                                     1
# survived                                   0
# sex                                   female
# age                                        2
# sibsp                                      1
# parch                                      2
# ticket                                113781
# fare                                  151.55
# cabin                                C22 C26
# embarked                                   S
# boat                                     NaN
# body                                     NaN
# home.dest    Montreal, PQ / Chesterville, ON
# Name: Allison, Miss. Helen Loraine, dtype: object

# %%
data.loc["Allison, Miss. Helen Loraine","fare"]
# Out:
# 151.55

# %%
data.loc["Allison, Miss. Helen Loraine","age"] = 200

# %%
data.iloc[0:5]
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                       1.0       1.0  female
# Allison, Master. Hudson Trevor                      1.0       1.0    male
# Allison, Miss. Helen Loraine                        1.0       0.0  female
# Allison, Mr. Hudson Joshua Creighton                1.0       0.0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)     1.0       0.0  female
#
#                                                       age  sibsp  parch  \
# name
# Allen, Miss. Elisabeth Walton                     29.0000    0.0    0.0
# Allison, Master. Hudson Trevor                     0.9167    1.0    2.0
# Allison, Miss. Helen Loraine                     200.0000    1.0    2.0
# Allison, Mr. Hudson Joshua Creighton              30.0000    1.0    2.0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)   25.0000    1.0    2.0
#
# ...

# %%
data[data["age"]>30]
# Out:
#                                                     pclass  survived     sex  \
# name
# Allison, Miss. Helen Loraine                           1.0       0.0  female
# Anderson, Mr. Harry                                    1.0       1.0    male
# Andrews, Miss. Kornelia Theodosia                      1.0       1.0  female
# Andrews, Mr. Thomas Jr                                 1.0       0.0    male
# Appleton, Mrs. Edward Dale (Charlotte Lamson)          1.0       1.0  female
# Artagaveytia, Mr. Ramon                                1.0       0.0    male
# Astor, Col. John Jacob                                 1.0       0.0    male
# Barkworth, Mr. Algernon Henry Wilson                   1.0       1.0    male
# Baxter, Mrs. James (Helene DeLaudeniere Chaput)        1.0       1.0  female
# Bazzani, Miss. Albina                                  1.0       1.0  female
# Beattie, Mr. Thomson                                   1.0       0.0    male
# ...

# %%
data[data["sex"]=="female"]
# Out:
#                                                     pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                          1.0       1.0  female
# Allison, Miss. Helen Loraine                           1.0       0.0  female
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)        1.0       0.0  female
# Andrews, Miss. Kornelia Theodosia                      1.0       1.0  female
# Appleton, Mrs. Edward Dale (Charlotte Lamson)          1.0       1.0  female
# Astor, Mrs. John Jacob (Madeleine Talmadge Force)      1.0       1.0  female
# Aubart, Mme. Leontine Pauline                          1.0       1.0  female
# Barber, Miss. Ellen "Nellie"                           1.0       1.0  female
# Baxter, Mrs. James (Helene DeLaudeniere Chaput)        1.0       1.0  female
# Bazzani, Miss. Albina                                  1.0       1.0  female
# Beckwith, Mrs. Richard Leonard (Sallie Monypeny)       1.0       1.0  female
# ...

# %%
data.loc[data["sex"]=="male","age"].mean()
# Out:
# 30.585232978723408

# %%
(data["age"]>65).sum()
# Out:
# 11
