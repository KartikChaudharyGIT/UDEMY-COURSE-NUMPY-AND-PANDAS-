# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
s1 = pd.Series(np.random.randn(10), index=np.arange(0,100,10))
s1.plot()

# %%
s2 = pd.DataFrame(np.random.randn(10,4),index= np.arange(0,100,10),columns = ["A","B","C","D"])
s2.head()
# Out:
#            A         B         C         D
# 0   0.129585 -0.152045  0.548367  0.963837
# 10  2.003829  0.618197 -0.044826  0.306635
# 20 -0.388676 -0.988566 -0.272684  0.168433
# 30  0.955195 -0.138510 -0.716051  0.617319
# 40 -0.941150  0.591083 -0.139840 -0.670833

# %%
s2.plot()

# %%
import matplotlib.pyplot as plt

# %%
data = pd.Series(np.random.randn(10), index=list("abjdbsjbjs"))
fi,axes = plt.subplots(1,2)
data.plot(ax=axes[0], kind="bar")
data.plot(ax=axes[1], kind="barh")

# %%
data1 = pd.DataFrame(np.random.randn(6,4),
                     index=["one","two","three","four","five","six"],
                     columns = pd.Index(["A","B","C","D"],name="Genius"))
data1
# Out:
# Genius         A         B         C         D
# one     0.680439 -1.044299 -0.249199  1.327603
# two     0.098373  1.138920  2.505391 -1.154717
# three  -0.635446  1.160308 -0.190967 -0.879982
# four   -0.161790 -0.035466 -0.272638  0.315746
# five    0.115595 -0.894879  0.761756 -0.016520
# six     0.929847 -0.387493 -1.001097 -0.626455

# %%
data1.head()
# Out:
# Genius         A         B         C         D
# one     0.680439 -1.044299 -0.249199  1.327603
# two     0.098373  1.138920  2.505391 -1.154717
# three  -0.635446  1.160308 -0.190967 -0.879982
# four   -0.161790 -0.035466 -0.272638  0.315746
# five    0.115595 -0.894879  0.761756 -0.016520

# %%
data1.plot(kind="bar")

# %%
data1.plot(kind="hist")
